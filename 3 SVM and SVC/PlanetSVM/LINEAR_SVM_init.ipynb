# %% [markdown]
# # LINEAR_SVM_init.ipynb

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import cross_val_predict, cross_validate
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn import metrics
#from astroML.datasets import fetch_LINEAR_geneva

# %%
#data = fetch_LINEAR_geneva()
#df = pd.DataFrame(data)
#df.to_csv('LINEAR.csv', index=False)
df = pd.read_csv('LINEAR.csv')
df
# Out:
#               ra        dec     ug     gi     iK     JK      logP   Ampl  \
# 0     119.526443  46.962120  1.166  0.369  1.018  0.269 -0.254138  0.619
# 1     119.324013  47.095505  1.356  0.521  1.167  0.311 -0.244691  0.709
# 2     118.503448  49.686569  1.166  0.138  1.154  0.384 -0.609386  0.601
# 3     119.712975  52.149574  1.175  0.386  1.100  0.205 -0.191591  0.487
# 4     118.491257  53.168125  0.805  0.554  1.618  0.198 -0.178900  0.695
# ...          ...        ...    ...    ...    ...    ...       ...    ...
# 6141  169.572021  -0.245896  1.107  0.383  1.200  0.451  0.173406  0.746
# 6142  168.000458  11.501586  1.463  0.664  1.193  0.431 -0.467688  0.388
# 6143  168.818787  12.683557  1.630  0.874  1.687  0.606 -0.117362  0.462
# 6144  169.745926 -14.120813  1.402  0.887  1.923  0.500 -0.527772  0.734
# 6145  168.388199 -14.626495  1.124  0.568  0.899  0.546 -0.468387  0.883
#
#        skew   kurt  magMed  nObs  LCtype  LINEARobjectID
# 0    -0.313 -0.567   16.37   301       1           29848
# 1    -0.493 -0.997   15.02   289       1           32086
# 2    -0.052 -0.447   16.14   245       1           43542
# 3    -0.291 -0.879   16.46   284       1           50402
# 4    -0.026 -1.059   14.08   274       1           61011
# ...     ...    ...     ...   ...     ...             ...
# 6141  2.564  6.464   15.95   434       5        24209652
# 6142  0.389 -0.602   14.17   535       5        24211479
# 6143  2.539  5.885   14.99   528       4        24215207
# 6144  1.139  0.511   16.83   104       5        24264418
# 6145  1.052  0.618   16.97    95       5        24265735
#
# [6146 rows x 14 columns]

# %%
df_reduced = df.drop(['ra','dec','LINEARobjectID','nObs','magMed'],axis=1).copy()
df_reduced
# Out:
#          ug     gi     iK     JK      logP   Ampl   skew   kurt  LCtype
# 0     1.166  0.369  1.018  0.269 -0.254138  0.619 -0.313 -0.567       1
# 1     1.356  0.521  1.167  0.311 -0.244691  0.709 -0.493 -0.997       1
# 2     1.166  0.138  1.154  0.384 -0.609386  0.601 -0.052 -0.447       1
# 3     1.175  0.386  1.100  0.205 -0.191591  0.487 -0.291 -0.879       1
# 4     0.805  0.554  1.618  0.198 -0.178900  0.695 -0.026 -1.059       1
# ...     ...    ...    ...    ...       ...    ...    ...    ...     ...
# 6141  1.107  0.383  1.200  0.451  0.173406  0.746  2.564  6.464       5
# 6142  1.463  0.664  1.193  0.431 -0.467688  0.388  0.389 -0.602       5
# 6143  1.630  0.874  1.687  0.606 -0.117362  0.462  2.539  5.885       4
# 6144  1.402  0.887  1.923  0.500 -0.527772  0.734  1.139  0.511       5
# 6145  1.124  0.568  0.899  0.546 -0.468387  0.883  1.052  0.618       5
#
# [6146 rows x 9 columns]

# %%
df_reduced.describe()
# Out:
#                 ug           gi           iK           JK         logP  \
# count  6146.000000  6146.000000  6146.000000  6146.000000  6146.000000
# mean      1.310343     0.412647     1.258091     0.375767    -0.368632
# std       0.345097     0.480758     0.483775     0.202392     0.205850
# min      -2.201000    -1.987000    -0.852000    -0.477000    -1.376182
# 25%       1.150000     0.110000     0.938000     0.236000    -0.515704
# 50%       1.197000     0.316000     1.169000     0.354000    -0.344812
# 75%       1.342000     0.674000     1.484000     0.515000    -0.230275
# max       2.750000     3.615000     5.398000     1.189000     1.529000
#
#               Ampl         skew         kurt       LCtype
# count  6146.000000  6146.000000  6146.000000  6146.000000
# mean      0.524334     0.401108     1.699075     2.835991
# std       2.229626     1.275248     9.920221     1.857874
# min     -99.990000    -2.407000    -1.631000     1.000000
# 25%       0.416000    -0.402000    -0.904000     1.000000
# 50%       0.536000     0.158000    -0.526000     2.000000
# 75%       0.706000     0.754750     0.284000     5.000000
# max       1.651000    12.665000   195.465000     6.000000

# %% [markdown]
# Ampl has -99 or some crazy number because we couldn't have NAN back in the days.

# %%
df_reduced.mean()/df_reduced.median()
# Out:
# ug        1.094689
# gi        1.305845
# iK        1.076211
# JK        1.061490
# logP      1.069083
# Ampl      0.978235
# skew      2.538659
# kurt     -3.230180
# LCtype    1.417995
# dtype: float64

# %%
np.mean(df_reduced, axis=0)/np.median(df_reduced, axis=0)
# Out:
# ug        1.094689
# gi        1.305845
# iK        1.076211
# JK        1.061490
# logP      1.069083
# Ampl      0.978235
# skew      2.538659
# kurt     -3.230180
# LCtype    1.417995
# dtype: float64

# %%
#Inter quartile range (IQR) is the difference between the 75th and 25th percentiles of the data. It is a measure of statistical dispersion and can be used to identify outliers in the data. A common rule of thumb is that any data point that is more than 1.5 times the IQR above the 75th percentile or below the 25th percentile is considered an outlier.
IQR = np.percentile(df_reduced, 75, axis=0) - np.percentile(df_reduced, 25, axis=0)
IQR
# Out:
# array([0.192     , 0.564     , 0.546     , 0.279     , 0.28542878,
#        0.29      , 1.15675   , 1.188     , 4.        ])

# %%
np.std(df_reduced,axis=0)/(IQR/2)
# Out:
# ug         3.594470
# gi         1.704676
# iK         1.771926
# JK         1.450724
# logP       1.442272
# Ampl      15.375483
# skew       2.204702
# kurt      16.699350
# LCtype     0.928862
# dtype: float64

# %%
#remove outliers using 5 sigma
